# %%
import pandas as pd

# %%
df = pd.read_csv("pandas/data/GBvideos.csv")
# dataya kaggledan ulaşabilirsiniz : https://www.kaggle.com/datasets/datasnaek/youtube-new?select=GBvideos.csv

# %% [markdown]
# ilk 10 kaydı getiriniz

# %%
df.head(10)
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
# 5  AumaWl0TNBo      17.14.11
# 6  2Vv-BfVoq4g      17.14.11
# 7  -N5eucPMTTc      17.14.11
# 8  LMCuKltaY3M      17.14.11
# 9  9t9u_yPEidY      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
# 5                       How My Relationship Started!
# 6        Ed Sheeran - Perfect (Official Music Video)
# 7                      CHRISTMAS HAS GONE TO MY HEAD
# 8   Elbow - Golden Slumbers (John Lewis Advert 2017)
# 9  Jennifer Lopez - Amor, Amor, Amor (Official Vi...
#
# ...

# %% [markdown]
# ikinci 5 kaydı alın

# %%
df[5:10].head()
# Out:
#       video_id trending_date  \
# 5  AumaWl0TNBo      17.14.11
# 6  2Vv-BfVoq4g      17.14.11
# 7  -N5eucPMTTc      17.14.11
# 8  LMCuKltaY3M      17.14.11
# 9  9t9u_yPEidY      17.14.11
#
#                                                title       channel_title  \
# 5                       How My Relationship Started!  PointlessBlogVlogs
# 6        Ed Sheeran - Perfect (Official Music Video)          Ed Sheeran
# 7                      CHRISTMAS HAS GONE TO MY HEAD          MoreZoella
# 8   Elbow - Golden Slumbers (John Lewis Advert 2017)           ElbowVEVO
# 9  Jennifer Lopez - Amor, Amor, Amor (Official Vi...   JenniferLopezVEVO
#
#    category_id              publish_time  \
# 5           24  2017-11-11T17:00:00.000Z
# 6           10  2017-11-09T11:04:14.000Z
# 7           22  2017-11-10T19:19:43.000Z
# 8           10  2017-11-10T08:00:01.000Z
# 9           10  2017-11-10T15:00:00.000Z
#
#                                                 tags     views    likes  \
# ...

# %% [markdown]
# Dataset'de bulunan kolon isimleri ve sayısını bulunuz.

# %%
result = df.columns
result
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
len(result)
# Out:
# 16

# %% [markdown]
# aşağıda bulunan bazı kolonları silin ve kalan kolonları listeleyiniz
#
# (thumbnail_link , 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description')

# %%
df.drop(['thumbnail_link', 'comments_disabled', 'ratings_disabled',
       'video_error_or_removed','description' ], axis = 1, inplace=True)

# %%
result = df.columns
result
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count'],
#       dtype='object')

# %% [markdown]
# Like ve dislike sayılarının ortalamasını bulunuz.

# %%
df["likes"].mean()
# Out:
# 134519.55349984582

# %%
df["dislikes"].mean()
# Out:
# 7612.559975331483

# %% [markdown]
# ilk 50 videonun like ve dislike kolonlarını getiriniz

# %%
df["likes"][0:50]
# Out:
# 0       55681
# 1       25561
# 2      787420
# 3         193
# 4          30
# 5       52708
# 6     1634124
# 7       57309
# 8        2163
# 9      190084
# 10       9591
# 11       1746
# 12      37986
# 13       8133
# 14      98804
# 15      12553
# 16      22326
# 17     286269
# 18     202676
# 19      72593
# 20      10028
# 21     263918
# 22     207262
# 23      25115
# 24       4577
# 25      52829
# 26        629
# 27       5029
# 28     307435
# 29        399
# 30       5364
# 31       7999
# 32      84426
# 33       1881
# 34        240
# 35     126078
# 36         33
# 37       1267
# 38       4604
# 39      53572
# 40       4935
# 41      19323
# 42       9210
# 43      32648
# 44       3946
# 45      11107
# 46      22303
# 47       3872
# 48      65854
# 49      14303
# Name: likes, dtype: int64

# %%
df["dislikes"][0:50]
# Out:
# 0     10247
# 1      2294
# 2     43420
# 3        12
# 4         2
# 5      1431
# 6     21082
# 7       749
# 8       147
# 9     15015
# 10      266
# 11      125
# 12      816
# 13     2693
# 14    11682
# 15     2146
# 16      833
# 17     4083
# 18     3394
# 19     1830
# 20      248
# 21     1502
# 22     3167
# 23      499
# 24      292
# 25     1524
# 26       77
# 27       81
# 28     2573
# 29       14
# 30      153
# 31       84
# 32     1130
# 33      182
# 34       16
# 35    10294
# 36        6
# 37       38
# 38       46
# 39      168
# 40      177
# 41      245
# 42       71
# 43     6221
# 44      295
# 45      212
# 46      700
# 47       16
# 48     2442
# 49      398
# Name: dislikes, dtype: int64

# %% [markdown]
# en çok görüntülenen video hangisidir

# %%
df["title"][df["views"].argmax()]
# Out:
# 'Nicky Jam x J. Balvin - X (EQUIS) | Video Oficial | Prod. Afro Bros & Jeon'

# %% [markdown]
# en düşük görüntülenen video hangisidir

# %%
df["title"][df["views"].argmin()]
# Out:
# 'Mountain Bikers Worried About Military Land Being Fenced Off'

# %% [markdown]
# en fazla görüntülenen ilk 10 video hangisidir?

# %%
df.sort_values("views",ascending = False).head(10)[["title","views"]]
# Out:
#                                                    title      views
# 28412  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912
# 28212  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  413586699
# 28008  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  402650804
# 27811  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  392036878
# 27615  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  382401497
# 27424  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  372399338
# 27241  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  362111555
# 27052  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  349987176
# 26861  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  339629489
# 34460  Te Bote Remix - Casper, Nio García, Darell, Ni...  337621571

# %% [markdown]
# Kategoriye göre beğeni ortalamalarını sıralı şekilde getiriniz

# %%
df.groupby("category_id").mean().sort_values("likes")["likes"]
# Out:
# <ipython-input-70-ffd359ac8517>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("category_id").mean().sort_values("likes")["likes"]
# category_id
# 19      9674.447917
# 2      24608.506944
# 25     25021.685714
# 26     26639.183091
# 15     28629.913858
# 27     38440.687090
# 20     39220.127517
# 17     39270.313057
# 43     41836.900000
# 22     46273.495899
# 1      57205.523089
# 28     61531.127413
# 23     78431.168490
# 24     81572.362012
# 29    271695.733333
# 10    272138.508943
# Name: likes, dtype: float64

# %% [markdown]
# katogoriye göre yorum sayılarını yukarıdan aşağıya sıralayınız

# %%
df.groupby("category_id").sum().sort_values("comment_count", ascending = False)["comment_count"]
# Out:
# <ipython-input-71-955c30a7700f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("category_id").sum().sort_values("comment_count", ascending = False)["comment_count"]
# category_id
# 10    293013140
# 24    116897440
# 22     18713149
# 23     16718816
# 1      15590011
# 17     10056226
# 25      9386604
# 29      7672790
# 26      7356296
# 20      6166994
# 28      4029065
# 27      1636903
# 15      1404698
# 2        505085
# 19       118177
# 43        80957
# Name: comment_count, dtype: int64

# %% [markdown]
# her kategoride kaç video var

# %%
df["category_id"].value_counts()
# Out:
# 10    13754
# 24     9124
# 22     2926
# 1      2577
# 26     1928
# 17     1907
# 23     1828
# 20     1788
# 25     1225
# 15      534
# 28      518
# 27      457
# 2       144
# 19       96
# 29       90
# 43       20
# Name: category_id, dtype: int64

# %% [markdown]
# her videonun title uzunluğu bilgisini yeni bir kolonda gösteriniz

# %%
df["title_len"] = df["title"].apply(len)
df["title_len"]
# Out:
# 0        45
# 1        41
# 2        42
# 3        76
# 4        55
#          ..
# 38911    61
# 38912    51
# 38913    34
# 38914    75
# 38915    51
# Name: title_len, Length: 38916, dtype: int64

# %% [markdown]
# her video için kullanılan tag sayısını yeni kolonda gösteriniz

# %%
df["tag_count"] = df["tags"].apply(lambda x: len(x.split('|')))
df["tag_count"]
# Out:
# 0         9
# 1        36
# 2         6
# 3         9
# 4         1
#          ..
# 38911     4
# 38912    41
# 38913    17
# 38914     8
# 38915    18
# Name: tag_count, Length: 38916, dtype: int64

# %% [markdown]
# en popüler videoları listeleyiniz. (like/dislike oranına göre)

# %%
def likedislikeoranhesapla(dataset):
  likeList = list(df["likes"])
  dislikeList = list(df["dislikes"])

  liste = list(zip(likeList,dislikeList))

  oranListesi = []
  for like, dislike in liste:
    if (like + dislike) == 0:
      oranListesi.append(0)
    else:
      oranListesi.append(like/(like+dislike))
  return oranListesi

# %%
df["begeni_orani"] = likedislikeoranhesapla(df)
df.sort_values("begeni_orani",ascending=False)[["title","likes","dislikes","begeni_orani"]]
# Out:
#                                                    title  likes  dislikes  \
# 36631         Kris Wu – Like That (Official Music Video)  57544         0
# 7088      HIGHLIGHTS: MK Dons U18s 1-0 Cardiff City U18s     30         0
# 5361         QUIZ : Name the Trail : A Christmas Cracker      2         0
# 12082    Lima Sopoaga Tribute🔥🔥||The Unsung Hero||💯 2017     50         0
# 5338   Bohemian Rhapsody (2018) - Scene Bohemian Rhap...     71         0
# ...                                                  ...    ...       ...
# 21547                                    To Our Daughter      0         0
# 22661                      【公式】「劇場版ポケットモンスター みんなの物語」予告編1      0         0
# 24920                    映画『BLEACH』特報【HD】2018年7月20日（金）公開      0         0
# 14864                             Altwork 1 Minute Video      0         0
# 4465                      The New Snapchat in 60 Seconds      0         0
#
#        begeni_orani
# 36631           1.0
# 7088            1.0
# ...
