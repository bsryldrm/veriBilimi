# %%
import pandas as pd

# %%
pandas_series = pd.Series()
print(pandas_series)
# Out:
# Series([], dtype: float64)
# <ipython-input-4-71ed2939bfa7>:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pandas_series = pd.Series()

# %%
#data
numbers = [20,30,40,50]
pandas_series = pd.Series(numbers)
print(pandas_series)
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# dtype: int64

# %%
letters = ["a","b","c","d"]
pandas_series = pd.Series(letters)
print(pandas_series)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
data = ["a","b","c","d",20,40]  # faklı data tipinde veriler içerir.
pandas_series = pd.Series(data)
print(pandas_series)
# Out:
# 0     a
# 1     b
# 2     c
# 3     d
# 4    20
# 5    40
# dtype: object

# %%
dict = {"a":10, "b":20, "c": 30, "d":40}
pandas_series = pd.Series(dict)
print(pandas_series)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
import numpy as np
random_numbers = np.random.randint(10,100,6)
pandas_series = pd.Series(random_numbers)
print(pandas_series)
# Out:
# 0    42
# 1    38
# 2    85
# 3    79
# 4    50
# 5    83
# dtype: int64

# %%
pandas_series = pd.Series(numbers, ["a","b","c","d"])
result = pandas_series[0]
print(pandas_series)
print(result)
# Out:
# a    20
# b    30
# c    40
# d    50
# dtype: int64
# 20

# %%
pandas_series.ndim  # series 1 boyutludur
# Out:
# 1

# %%
pandas_series.dtype
# Out:
# dtype('int64')

# %%
pandas_series.shape
# Out:
# (4,)

# %%
pandas_series.sum()
# Out:
# 140

# %%
pandas_series.max()
# Out:
# 50

# %%
pandas_series.min()
# Out:
# 20

# %%
pandas_series +pandas_series
# Out:
# a     40
# b     60
# c     80
# d    100
# dtype: int64

# %%
pandas_series + 5
# Out:
# a    25
# b    35
# c    45
# d    55
# dtype: int64
