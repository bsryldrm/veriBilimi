# %% [markdown]
# NumPy'de bulunan toplamlar, bir dizi değeri özetlemek için son derece yararlı olabilir. Basit bir örnek olarak tüm ABD başkanlarının boylarını ele alalım. Bu veriler, virgülle ayrılmış basit bir etiket ve değer listesi olan President_heights.csv dosyasında mevcuttur:

# %%
# !head -4 data/president_heights.csv
# Out:
# order,name,height(cm)
# 1,George Washington,189
# 2,John Adams,170
# 3,Thomas Jefferson,189

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('data/president_heights.csv')
heights = np.array(data['height(cm)'])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183
#  177 185 188 188 182 185]

# %%
print("Mean height:       ", heights.mean())
print("Standard deviation:", heights.std())
print("Minimum height:    ", heights.min())
print("Maximum height:    ", heights.max())
# Out:
# Mean height:        179.73809523809524
# Standard deviation: 6.931843442745892
# Minimum height:     163
# Maximum height:     193

# %%
print("25th percentile:   ", np.percentile(heights, 25))
print("Median:            ", np.median(heights))
print("75th percentile:   ", np.percentile(heights, 75))
# Out:
# 25th percentile:    174.25
# Median:             182.0
# 75th percentile:    183.0

# %% [markdown]
# ABD başkanlarının ortalama boylarının 182 cm, yani 1,80 civarında olduğunu görüyoruz.
#
# bazen bu verilerin görsel temsilini görmek daha yararlı olabilir, bunu Matplotlib ile grafiği oluşturulur:

# %%
import matplotlib.pyplot as plt
plt.hist(heights)
plt.title('Height Distribution of US Presidents')
plt.xlabel('height (cm)')
plt.ylabel('number')
# Out:
# Text(0, 0.5, 'number')
