# %%
import numpy as np

# %%
numbers1 = np.random.randint(10,100,6)
numbers2 = np.random.randint(10,100,6)

# %%
numbers1
# Out:
# array([86, 48, 25, 27, 38, 18])

# %%
numbers2
# Out:
# array([16, 33, 59, 54, 18, 78])

# %%
result = numbers1 + numbers2
result
# Out:
# array([102,  81,  84,  81,  56,  96])

# %%
numbers1 + 10   # her bir elemanı 1 ile toplanır
# Out:
# array([96, 58, 35, 37, 48, 28])

# %%
result = np.sin(numbers1)
result
# Out:
# array([-0.92345845, -0.76825466, -0.13235175,  0.95637593,  0.29636858,
#        -0.75098725])

# %%
result = np.cos(numbers1)
result
# Out:
# array([-0.38369844, -0.64014434,  0.99120281, -0.29213881,  0.95507364,
#         0.66031671])

# %%
mnumbers1 = numbers1.reshape(2,3)
mnumbers2 = numbers2.reshape(2,3)

# %%
mnumbers1
# Out:
# array([[86, 48, 25],
#        [27, 38, 18]])

# %%
mnumbers2
# Out:
# array([[16, 33, 59],
#        [54, 18, 78]])

# %%
result = np.vstack((mnumbers1,mnumbers2)) #dikey bir şekilde ekleme yaptı
result
# Out:
# array([[86, 48, 25],
#        [27, 38, 18],
#        [16, 33, 59],
#        [54, 18, 78]])

# %%
result = np.hstack((mnumbers1,mnumbers2)) #yatay bir şekilde ekleme yaptı
result
# Out:
# array([[86, 48, 25, 16, 33, 59],
#        [27, 38, 18, 54, 18, 78]])

# %%
result = numbers1 >= 30
result
# Out:
# array([ True,  True, False, False,  True, False])

# %%
result = numbers1 % 2 == 0
result
# Out:
# array([ True,  True, False, False,  True,  True])
